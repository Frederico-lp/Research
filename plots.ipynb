# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Cardio

# %%
x = np.array([0.8153809523809524, 0.8663809523809524, 0.8568571428571429])
y = np.array([0.01632538, 0.02066531, 0.02155056])
colors = np.array(['red', 'green', 'blue'])

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### Heart

# %%
x = np.array([0.8351428571428572, 0.8071428571428572, 0.6596666666666666])
y = np.array([0.1416652, 0.16371378, 0.15526526])
colors = np.array(['red', 'green', 'blue'])

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### Epileptic

# %%
#dpctgan only 2 epochs
x = np.array([0.7568115942028986, 0.5681159420289855, 0.6089855072463768])
y = np.array([0.06226404, 0.06098812, 0.06031706])

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### Diabetes

# %%
x = np.array([0.8324761904761905, 0.8418571428571429, 0.7594285714285715])
y = np.array([0.15249756, 0.14473098, 0.1483853])

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### Breast Cancer

# %%
x = np.array([0.5555555555555556, 0.9005847953216374, 0.9181286549707602])
y = np.array([0.21770119, 0.13428222, 0.1617649])

plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### All

# %%
# x = np.array([0.8153809523809524, 0.8663809523809524, 0.8568571428571429])
# y = np.array([0.01632538, 0.02066531, 0.02155056])
# plt.scatter(x, y)

# x = np.array([0.8351428571428572, 0.8071428571428572, 0.6596666666666666])
# y = np.array([0.1416652, 0.16371378, 0.15526526])
# plt.scatter(x, y)

# x = np.array([0.7568115942028986, 0.5681159420289855, 0.6089855072463768])
# y = np.array([0.06226404, 0.06098812, 0.06031706])
# plt.scatter(x, y)

# x = np.array([0.8324761904761905, 0.8418571428571429, 0.7594285714285715])
# y = np.array([0.15249756, 0.14473098, 0.1483853])
# plt.scatter(x, y)

# x = np.array([0.5555555555555556, 0.9005847953216374, 0.9181286549707602])
# y = np.array([0.21770119, 0.13428222, 0.1617649])
# plt.scatter(x, y)

x = np.array([0.76, 0.60, 0.55, 0.59, 0.82, 0.83, 0.76, 0.83, 0.61, 0.76])
y = np.array([0.10, 0.096, 0.33, 0.12, 0.02, 0.14, 0.06, 0.15, 0.22, 0.19])
plt.scatter(x, y, c="red")

x = np.array([0.81, 0.82, 0.76, 0.63, 0.87, 0.71, 0.74, 0.74, 0.92, 0.73])
y = np.array([0.07, 0.08, 0.33, 0.098, 0.02, 0.16, 0.06, 0.14, 0.135, 0.14])
plt.scatter(x, y, c="green")

x = np.array([0.70, 0.63, 0.63, 0.71, 0.86, 0.63, 0.73, 0.72, 0.94, 0.67])
y = np.array([0.07, 0.09, 0.34, 0.12, 0.02, 0.16, 0.06, 0.15, 0.16, 0.18])
plt.scatter(x, y, c="blue")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x_dpctgan = np.array([0.76, 0.60, 0.55, 0.59, 0.82, 0.83, 0.76, 0.83, 0.61, 0.76])
y_dpctgan  = np.array([0.10, 0.096, 0.33, 0.12, 0.02, 0.14, 0.06, 0.15, 0.22, 0.19])
#plt.scatter(x, y, c="red")

x_fpgan = np.array([0.70, 0.63, 0.63, 0.71, 0.86, 0.63, 0.73, 0.72, 0.94, 0.67])
y_fpgan = np.array([0.07, 0.09, 0.34, 0.12, 0.02, 0.16, 0.06, 0.15, 0.16, 0.18])

X1 = []
Y1 = []
for i in range(len(x_dpctgan)):
    X1.append(x_fpgan[i] - x_dpctgan[i])
    Y1.append(y_fpgan[i] - y_dpctgan[i])

plt.scatter(X1, Y1, marker="v")

# %%
x_ctgan = np.array([0.81, 0.82, 0.76, 0.63, 0.87, 0.71, 0.74, 0.74, 0.92, 0.73])
y_ctgan = np.array([0.07, 0.08, 0.33, 0.098, 0.02, 0.16, 0.06, 0.14, 0.135, 0.14])

x_fpgan = np.array([0.70, 0.63, 0.63, 0.71, 0.86, 0.63, 0.73, 0.72, 0.94, 0.67])
y_fpgan = np.array([0.07, 0.09, 0.34, 0.12, 0.02, 0.16, 0.06, 0.15, 0.16, 0.18])

X2 = []
Y2 = []
for i in range(len(x_ctgan)):
    X2.append(x_fpgan[i] - x_ctgan[i])
    Y2.append(y_fpgan[i] - y_ctgan[i])

plt.scatter(X2, Y2, marker="^")

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.markers as mmark
import matplotlib.lines as mlines

x_dpctgan = np.array([0.76, 0.60, 0.55, 0.59, 0.82, 0.83, 0.76, 0.83, 0.61, 0.76])
y_dpctgan  = np.array([0.10, 0.096, 0.33, 0.12, 0.02, 0.14, 0.06, 0.15, 0.22, 0.19])
#plt.scatter(x, y, c="red")

x_fpgan = np.array([0.70, 0.63, 0.63, 0.71, 0.86, 0.63, 0.73, 0.72, 0.94, 0.67])
y_fpgan = np.array([0.07, 0.09, 0.34, 0.12, 0.02, 0.16, 0.06, 0.15, 0.16, 0.18])

X1 = []
Y1 = []
for i in range(len(x_dpctgan)):
    X1.append(x_fpgan[i] - x_dpctgan[i])
    Y1.append(y_fpgan[i] - y_dpctgan[i])

plt.scatter(X1, Y1, marker="P", c="blue")

x_ctgan = np.array([0.81, 0.82, 0.76, 0.63, 0.87, 0.71, 0.74, 0.74, 0.92, 0.73])
y_ctgan = np.array([0.07, 0.08, 0.33, 0.098, 0.02, 0.16, 0.06, 0.14, 0.135, 0.14])

X2 = []
Y2 = []
for i in range(len(x_ctgan)):
    X2.append(x_fpgan[i] - x_ctgan[i])
    Y2.append(y_fpgan[i] - y_ctgan[i])

plt.scatter(X2, Y2, marker="X", c="red")

# list_mak = [mmark.MarkerStyle('v'),mmark.MarkerStyle('^')]
# list_lab = ['PCTGAN - DP_CTGAN','PCTGAN - CTGAN']
# list_lab = ['1','2']

blue_inv_triangle = mlines.Line2D([], [], color='blue', marker='P', linestyle='None',
                          markersize=10, label='PCTGAN - DP-CTGAN')

red_triangle = mlines.Line2D([], [], color='red', marker='X', linestyle='None',
                          markersize=10, label='PCTGAN - CTGAN')

plt.legend(handles=[blue_inv_triangle, red_triangle], loc='upper right')

plt.xlabel("Fidelity")
plt.ylabel("Privacy")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.markers as mmark
import matplotlib.lines as mlines

x_dpctgan = np.array([0.76, 0.60, 0.55, 0.59, 0.82, 0.83, 0.76, 0.83, 0.61, 0.76])
y_dpctgan  = np.array([0.10, 0.096, 0.33, 0.12, 0.02, 0.14, 0.06, 0.15, 0.22, 0.19])
#plt.scatter(x, y, c="red")

x_fpgan = np.array([0.70, 0.45, 0.64, 0.40, 0.35, 0.60, 0.70, 0.58, 0.73, 0.63])
y_fpgan = np.array([0.08, 0.12, 0.34, 0.13, 0.51, 0.15, 0.07, 0.19, 0.27, 0.20])

X1 = []
Y1 = []
for i in range(len(x_dpctgan)):
    X1.append(x_fpgan[i] - x_dpctgan[i])
    Y1.append(y_fpgan[i] - y_dpctgan[i])

plt.scatter(X1, Y1, marker="P", c="blue")

x_ctgan = np.array([0.81, 0.82, 0.76, 0.63, 0.87, 0.71, 0.74, 0.74, 0.92, 0.73])
y_ctgan = np.array([0.07, 0.08, 0.33, 0.098, 0.02, 0.16, 0.06, 0.14, 0.135, 0.14])

X2 = []
Y2 = []
for i in range(len(x_ctgan)):
    X2.append(x_fpgan[i] - x_ctgan[i])
    Y2.append(y_fpgan[i] - y_ctgan[i])

plt.scatter(X2, Y2, marker="X", c="red")

# list_mak = [mmark.MarkerStyle('v'),mmark.MarkerStyle('^')]
# list_lab = ['PCTGAN - DP_CTGAN','PCTGAN - CTGAN']
# list_lab = ['1','2']

blue_inv_triangle = mlines.Line2D([], [], color='blue', marker='P', linestyle='None',
                          markersize=10, label='PCTGAN - DP-CTGAN')

red_triangle = mlines.Line2D([], [], color='red', marker='X', linestyle='None',
                          markersize=10, label='PCTGAN - CTGAN')

plt.legend(handles=[blue_inv_triangle, red_triangle], loc='upper right')

plt.xlabel("Fidelity")
plt.ylabel("Privacy")

plt.show()

# %%
# Dataset & Real & DP-CTGAN & CTGAN & FPGAN \\ 
# Cardio & 0.73 & 0.68 & 0.70 & 0.68/0.44  \\
# Heart & 0.75 & 0.65 & 0.57 & 0.53/0.55   \\
# Epilepsy & 0.91 & 0.62 & 0.72 & 0.77 \\
# Diabetes & 0.75 &  0.71 & 0.73 & 0.59/0.53\\
# Breast & 0.95 & 0.60 & 0.60 & 0.91/0.77 \\
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Bankruptcy & 0.83 & 0.29 & 0.49 & 0.56/0.57 \\
# Census & 0.81 & 0.53 & 0.72 & 0.49/0.38 \\
# Fetal & 0.93 & 0.60 & 0.59 & 0.52/0.53 \\
# Lungs & 1 & 0.56 & 0.71 & 0.55/0.57 \\
# Credit & 0.94 & 0.57 & 0.59 & 0.67/0.46 \\

real = [0.73, 0.75, 0.91, 0.75, 0.95, 0.83, 0.81, 0.93, 1, 0.94]
dpctgan = [0.68, 0.65, 0.62, 0.71, 0.60, 0.29, 0.53, 0.60, 0.56, 0.57]
ctgan = [0.70, 0.57, 0.72, 0.73, 0.60, 0.49, 0.72, 0.59, 0.71, 0.59]
fpgan = [0.68, 0.53, 0.77, 0.59, 0.91, 0.56, 0.49, 0.52, 0.55, 0.67]

fpgan25 = [0.44, 0.55, 0.66, 0.53, 0.77, 0.57, 0.38, 0.53, 0.57, 0.46]


rate_dpctgan = []
rate_ctgan = []
rate_fpgan = []
rate_fpgan25 = []

for i in range(len(real)):
    rate_dpctgan.append(round(( (dpctgan[i] - real[i]) / real[i] ), 2))
    rate_ctgan.append(round(( (ctgan[i] - real[i]) / real[i] ), 2))
    rate_fpgan.append(round(( (fpgan[i] - real[i]) / real[i] ), 2))
    rate_fpgan25.append(round(( (fpgan25[i] - real[i]) / real[i] ), 2))


print(rate_dpctgan)
print(rate_ctgan)
print(rate_fpgan)
print(rate_fpgan25)
# Out:
# [-0.07, -0.13, -0.32, -0.05, -0.37, -0.65, -0.35, -0.35, -0.44, -0.39]
# [-0.04, -0.24, -0.21, -0.03, -0.37, -0.41, -0.11, -0.37, -0.29, -0.37]
# [-0.07, -0.29, -0.15, -0.21, -0.04, -0.33, -0.4, -0.44, -0.45, -0.29]
# [-0.4, -0.27, -0.27, -0.29, -0.19, -0.31, -0.53, -0.43, -0.43, -0.51]

# %%
print(np.mean(real))
print(np.mean(dpctgan))
print(np.mean(ctgan))
print(np.mean(fpgan))
print(np.mean(fpgan25))

print(np.mean(rate_dpctgan))
print(np.mean(rate_ctgan))
print(np.mean(rate_fpgan))
print(np.mean(rate_fpgan25))
# Out:
# 0.86
# 0.5810000000000001
# 0.6419999999999999
# 0.627
# 0.546
# -0.312
# -0.244
# -0.267
# -0.363
