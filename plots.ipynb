# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Cardio

# %%
x = np.array([0.8153809523809524, 0.8663809523809524, 0.8568571428571429])
y = np.array([0.01632538, 0.02066531, 0.02155056])
colors = np.array(['red', 'green', 'blue'])

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### Heart

# %%
x = np.array([0.8351428571428572, 0.8071428571428572, 0.6596666666666666])
y = np.array([0.1416652, 0.16371378, 0.15526526])
colors = np.array(['red', 'green', 'blue'])

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### Epileptic

# %%
#dpctgan only 2 epochs
x = np.array([0.7568115942028986, 0.5681159420289855, 0.6089855072463768])
y = np.array([0.06226404, 0.06098812, 0.06031706])

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### Diabetes

# %%
x = np.array([0.8324761904761905, 0.8418571428571429, 0.7594285714285715])
y = np.array([0.15249756, 0.14473098, 0.1483853])

# %%
plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### Breast Cancer

# %%
x = np.array([0.5555555555555556, 0.9005847953216374, 0.9181286549707602])
y = np.array([0.21770119, 0.13428222, 0.1617649])

plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# ### All

# %%
# x = np.array([0.8153809523809524, 0.8663809523809524, 0.8568571428571429])
# y = np.array([0.01632538, 0.02066531, 0.02155056])
# plt.scatter(x, y)

# x = np.array([0.8351428571428572, 0.8071428571428572, 0.6596666666666666])
# y = np.array([0.1416652, 0.16371378, 0.15526526])
# plt.scatter(x, y)

# x = np.array([0.7568115942028986, 0.5681159420289855, 0.6089855072463768])
# y = np.array([0.06226404, 0.06098812, 0.06031706])
# plt.scatter(x, y)

# x = np.array([0.8324761904761905, 0.8418571428571429, 0.7594285714285715])
# y = np.array([0.15249756, 0.14473098, 0.1483853])
# plt.scatter(x, y)

# x = np.array([0.5555555555555556, 0.9005847953216374, 0.9181286549707602])
# y = np.array([0.21770119, 0.13428222, 0.1617649])
# plt.scatter(x, y)

x = np.array([0.8153809523809524, 0.8351428571428572, 0.7568115942028986, 0.8324761904761905, 0.5555555555555556])
y = np.array([0.01632538, 0.1416652, 0.06226404, 0.15249756, 0.21770119])
plt.scatter(x, y, c="red")

x = np.array([0.8663809523809524, 0.8071428571428572, 0.5681159420289855, 0.8418571428571429, 0.9005847953216374])
y = np.array([0.02066531, 0.16371378, 0.06098812, 0.14473098, 0.13428222])
plt.scatter(x, y, c="green")

x = np.array([0.8568571428571429, 0.6596666666666666, 0.6089855072463768, 0.7594285714285715, 0.9181286549707602])
y = np.array([0.02155056, 0.15526526, 0.06031706, 0.1483853, 0.1617649])
plt.scatter(x, y, c="blue")

plt.show()
